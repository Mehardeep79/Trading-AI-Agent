# %% [markdown]
# # 🤖 AI Trading Agent with Deep Q-Learning
#
# ## 📋 Project Overview
#
# This notebook implements an intelligent trading agent using **Deep Q-Network (DQN)** reinforcement learning to automate stock trading decisions. The AI agent learns to maximize profits by making optimal BUY, SELL, or HOLD decisions based on real-time market data and technical indicators.
#
# ## 🛠️ Technology Stack
#
# - **Python**: Core programming language
# - **PyTorch**: Deep learning framework for neural network implementation
# - **yfinance**: Real-time stock market data retrieval
# - **NumPy & Pandas**: Data manipulation and analysis

# %% [markdown]
# ## 📚 Import Libraries:

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\sandh\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in c:\users\sandh\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sandh\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sandh\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sandh\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\sandh\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\sandh\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\sandh\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sandh\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sandh\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\sandh\anaconda3\lib\site-packages (0.2.65)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\sandh\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sandh\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\sandh\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\sandh\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sandh\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sandh\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sandh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sandh\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\sandh\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\sandh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import yfinance as yf

# %%
# 🔧 Easy Stock Selection - Just change the symbol below!

print("🤖 AI Trading Agent - Stock Configuration")
print("=" * 50)
print("📈 Popular Stock Options:")
print("  💻 Tech Giants: AAPL, MSFT, GOOGL, META")
print("  🎮 AI/Semiconductors: NVDA, AMD, INTC") 
print("  🚗 Electric/Innovation: TSLA, RIVN")
print("  🛒 E-commerce/Streaming: AMZN, NFLX")
print("  📊 Market ETFs: SPY, QQQ")
print("=" * 50)

# 🎯 CHANGE THIS LINE TO SELECT YOUR STOCK:
symbol = "MSFT"  # ← Change this to any stock symbol you want!

# Examples (uncomment the one you want):
# symbol = "AAPL"    # Apple
# symbol = "TSLA"    # Tesla  
# symbol = "GOOGL"   # Google
# symbol = "MSFT"    # Microsoft
# symbol = "AMZN"    # Amazon
# symbol = "META"    # Meta/Facebook
# symbol = "SPY"     # S&P 500 ETF

# Date range configuration
start_date = "2020-01-01"
end_date = "2025-02-14"


print(f"\n🎯 Selected Configuration:")
print(f"   📈 Stock Symbol: {symbol}")
print(f"   📅 Date Range: {start_date} to {end_date}")
print(f"   🤖 AI will learn to trade {symbol} stock!")
print("🚀 Ready to download data and train your AI agent!")
# Out:
# 🤖 AI Trading Agent - Stock Configuration
# ==================================================
# 📈 Popular Stock Options:
#   💻 Tech Giants: AAPL, MSFT, GOOGL, META
#   🎮 AI/Semiconductors: NVDA, AMD, INTC
#   🚗 Electric/Innovation: TSLA, RIVN
#   🛒 E-commerce/Streaming: AMZN, NFLX
#   📊 Market ETFs: SPY, QQQ
# ==================================================
#
# 🎯 Selected Configuration:
#    📈 Stock Symbol: MSFT
#    📅 Date Range: 2020-01-01 to 2025-02-14
#    🤖 AI will learn to trade MSFT stock!
# 🚀 Ready to download data and train your AI agent!

# %% [markdown]
# ## 📥 Importing the Dataset:
#
# Downloading the historical data:

# %%
data = yf.download(symbol, start = start_date, end = end_date)
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3296095281.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start = start_date, end = end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
data.head(5)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-01-02  152.791138  152.895777  150.612762  151.040826  22622100
# 2020-01-03  150.888626  152.153802  150.355924  150.603260  21116200
# 2020-01-06  151.278625  151.345221  148.881450  149.423674  20813700
# 2020-01-07  149.899338  151.887465  149.652016  151.554533  21634100
# 2020-01-08  152.286987  152.962387  150.251294  151.183524  27746500

# %%
data.tail(5)
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-02-07  407.510773  416.362129  405.869796  414.204005  22886800
# 2025-02-10  409.967285  413.189569  408.674402  411.449133  20817900
# 2025-02-11  409.191528  410.235778  407.063209  407.401377  18140600
# 2025-02-12  406.804657  408.505304  402.160165  404.984641  19121700
# 2025-02-13  408.296478  408.753956  404.139298  404.775815  23891700

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1287 entries, 2020-01-02 to 2025-02-13
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, MSFT)   1287 non-null   float64
#  1   (High, MSFT)    1287 non-null   float64
#  2   (Low, MSFT)     1287 non-null   float64
#  3   (Open, MSFT)    1287 non-null   float64
#  4   (Volume, MSFT)  1287 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 60.3 KB

# %%
data.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         MSFT         MSFT         MSFT         MSFT          MSFT
# count   1287.000000  1287.000000  1287.000000  1287.000000  1.287000e+03
# mean     290.539006   293.328775   287.490299   290.464356  2.849457e+07
# std       83.061810    83.345099    82.692910    83.121283  1.268439e+07
# min      129.171295   134.083642   126.405093   130.687900  7.164500e+06
# 25%      229.263847   232.728552   226.439220   228.973963  2.032920e+07
# 50%      277.421692   280.525861   274.028938   277.534621  2.529610e+07
# 75%      346.300491   350.519538   339.587586   344.906182  3.276810e+07
# max      463.240967   464.023678   460.169610   462.686155  9.701270e+07

# %%
len(data)
# Out:
# 1287

# %% [markdown]
# ## ⚙️ Feature Engineering:
#
# Calculating technical indicators that help the AI agent make better trading decisions:

# %%
data['SMA_5'] = data['Close'].rolling(window = 5).mean()
data['SMA_20'] = data['Close'].rolling(window = 20).mean()
data['Returns'] = data['Close'].pct_change()

# %%
data
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-01-02  152.791138  152.895777  150.612762  151.040826  22622100
# 2020-01-03  150.888626  152.153802  150.355924  150.603260  21116200
# 2020-01-06  151.278625  151.345221  148.881450  149.423674  20813700
# 2020-01-07  149.899338  151.887465  149.652016  151.554533  21634100
# 2020-01-08  152.286987  152.962387  150.251294  151.183524  27746500
# ...                ...         ...         ...         ...       ...
# 2025-02-07  407.510773  416.362129  405.869796  414.204005  22886800
# 2025-02-10  409.967285  413.189569  408.674402  411.449133  20817900
# 2025-02-11  409.191528  410.235778  407.063209  407.401377  18140600
# 2025-02-12  406.804657  408.505304  402.160165  404.984641  19121700
# 2025-02-13  408.296478  408.753956  404.139298  404.775815  23891700
#
# Price            SMA_5      SMA_20   Returns
# Ticker
# Date
# 2020-01-02         NaN         NaN       NaN
# 2020-01-03         NaN         NaN -0.012452
# 2020-01-06         NaN         NaN  0.002585
# 2020-01-07         NaN         NaN -0.009118
# 2020-01-08  151.428943         NaN  0.015928
# ...                ...         ...       ...
# 2025-02-07  410.176135  423.348254 -0.014598
# 2025-02-10  410.434717  423.013594  0.006028
# 2025-02-11  410.249731  422.727664 -0.001892
# 2025-02-12  409.404370  422.397975 -0.005833
# 2025-02-13  408.354144  421.613785  0.003667
#
# [1287 rows x 8 columns]

# %% [markdown]
# ## 🧹 Data Cleaning:
#
# Dropping the missing values in the first 4 rows of SMA_5, first 19 rows of SMA_20 and first row of returns.
#
# Also reset the index by replacing dates with index numbers:

# %%
data.dropna(inplace = True)
data.reset_index(drop = True, inplace = True)

# %%
data
# Out:
# Price        Close        High         Low        Open    Volume       SMA_5  \
# Ticker        MSFT        MSFT        MSFT        MSFT      MSFT
# 0       164.358414  165.566516  162.465404  165.566516  51597500  158.593790
# 1       161.932739  163.996969  161.314427  163.816242  36142700  159.581198
# 2       165.880417  165.994563  162.094399  162.122935  30107000  161.883243
# 3       171.340652  171.835311  167.716360  168.505907  36433300  164.672333
# 4       171.131393  175.221808  169.714028  175.060096  39186300  166.928723
# ...            ...         ...         ...         ...       ...         ...
# 1263    407.510773  416.362129  405.869796  414.204005  22886800  410.176135
# 1264    409.967285  413.189569  408.674402  411.449133  20817900  410.434717
# 1265    409.191528  410.235778  407.063209  407.401377  18140600  410.249731
# 1266    406.804657  408.505304  402.160165  404.984641  19121700  409.404370
# 1267    408.296478  408.753956  404.139298  404.775815  23891700  408.354144
#
# Price       SMA_20   Returns
# Ticker
# 0       155.709109  0.028208
# 1       156.166189 -0.014758
# 2       156.915778  0.024379
# 3       157.918880  0.032917
# 4       158.980482 -0.001221
# ...            ...       ...
# 1263    423.348254 -0.014598
# 1264    423.013594  0.006028
# 1265    422.727664 -0.001892
# 1266    422.397975 -0.005833
# 1267    421.613785  0.003667
#
# [1268 rows x 8 columns]

# %% [markdown]
# ## 🎯 Action Space:
#
# The AI agent has three possible actions:
#
# **HOLD:** Do nothing.
#
# **BUY:** Purchase stocks.
#
# **SELL:** Sell held stocks.
#
# This action space is used to train the **Reinforcement Learning model**

# %%
ACTIONS = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %% [markdown]
# ## 🤖 State Of The Agent:
#
# This function extracts the state representation from the dataset at a given time index. The state is an array containing:
#
# - **Closing price**
# - **5-day SMA**
# - **20-day SMA**
# - **Daily return percentage**

# %%
# Function to get the state of the agent:

def get_state(data, index):
    return np.array([
        float(data.loc[index, 'Close']),
        float(data.loc[index, 'SMA_5']),
        float(data.loc[index, 'SMA_20']),
        float(data.loc[index, 'Returns'])
    ])

# %% [markdown]
# ## 🏢 Trading Environment:
#
# Building a trading environment to interact with the **Deep Q-Network (DQN) AI agent**, which will allow it to learn how to trade stocks profitably:

# %%
class TradingEnvironment:
    def __init__(self, data):
        self.data = data
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0

    def reset(self):
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0
        return get_state(self.data, self.index)

    def step(self, action):
        price = float(self.data.loc[self.index, 'Close'])
        reward = 0

        # Buy:
        if action == 1 and self.balance >= price: 
            self.holdings = self.balance // price
            self.balance -= self.holdings * price
        # Sell:
        elif action == 2 and self.holdings > 0:
            self.balance += self.holdings * price
            self.holdings = 0

        self.index += 1
        done = self.index >= len(self.data) - 1

        if done:
            reward = self.balance - self.initial_balance

        next_state = get_state(self.data, self.index) if not done else None
        return next_state, reward, done, {}

# %% [markdown]
# ## 🧠 Deep Q-Network (DQN):
#
# DQN is a neural network that approximates the Q-values for each state-action pair.
#
# Defining the neural network architecture for our Deep Q-Network, which will be responsible for predicting the best trading actions based on the stock market state:

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        # Three Layer Neural Network:
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        # ReLU activation:
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# It outputs Q-values, which the agent will utilize to determine the best action: buy, sell, or hold, based on market conditions.

# %% [markdown]
# ## 🎮 DQN Agent:
#
# Implementing the AI agent that learns how to trade stocks using Deep Q-Learning.
#
# The DQN Agent will interact with the trading environment, make trading decisions (BUY, SELL, HOLD), store experiences, and learn from past experiences to improve future decisions:

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(ACTIONS.keys()))
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target

            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# ## 🏋️ Training the AI Agent:
#
# Training involves running multiple episodes where the agent interacts with the environment, learns from experience, and updates its model.

# %%
env = TradingEnvironment(data)
agent = DQNAgent(state_size = 4, action_size = 3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\716196290.py:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Episode 1/500, Total Reward: -9695.471099853516
# Episode 2/500, Total Reward: -9812.841506958008
# Episode 3/500, Total Reward: -9776.794815063477
# Episode 4/500, Total Reward: -9860.119888305664
# Episode 5/500, Total Reward: 6574.522933959961
# Episode 6/500, Total Reward: -9787.687606811523
# Episode 7/500, Total Reward: -9748.887634277344
# Episode 8/500, Total Reward: -9791.44482421875
# Episode 9/500, Total Reward: -9800.838317871094
# Episode 10/500, Total Reward: -9839.546798706055
# Episode 11/500, Total Reward: -9730.093246459961
# Episode 12/500, Total Reward: 7410.813034057617
# Episode 13/500, Total Reward: -9952.489974975586
# Episode 14/500, Total Reward: -9786.74478149414
# Episode 15/500, Total Reward: -9646.296310424805
# Episode 16/500, Total Reward: -9848.02555847168
# Episode 17/500, Total Reward: -9780.802047729492
# Episode 18/500, Total Reward: -9869.890899658203
# Episode 19/500, Total Reward: -9851.046890258789
# Episode 20/500, Total Reward: -9967.473693847656
# Episode 21/500, Total Reward: -9668.168807983398
# Episode 22/500, Total Reward: -9794.02409362793
# Episode 23/500, Total Reward: 1380.589126586914
# Episode 24/500, Total Reward: 1936.6827697753906
# Episode 25/500, Total Reward: -9928.286514282227
# Episode 26/500, Total Reward: 19281.668090820312
# Episode 27/500, Total Reward: -9950.336151123047
# Episode 28/500, Total Reward: -9763.944931030273
# Episode 29/500, Total Reward: -9571.102737426758
# Episode 30/500, Total Reward: -9705.540344238281
# Episode 31/500, Total Reward: -9656.340774536133
# Episode 32/500, Total Reward: -9749.604705810547
# Episode 33/500, Total Reward: -9856.784423828125
# Episode 34/500, Total Reward: -9775.418441772461
# Episode 35/500, Total Reward: -9978.732559204102
# Episode 36/500, Total Reward: 2533.3418884277344
# Episode 37/500, Total Reward: 7381.372299194336
# Episode 38/500, Total Reward: -9988.831726074219
# Episode 39/500, Total Reward: -9736.896942138672
# Episode 40/500, Total Reward: -9773.288681030273
# Episode 41/500, Total Reward: 11169.500793457031
# Episode 42/500, Total Reward: -9869.166061401367
# Episode 43/500, Total Reward: -521.03466796875
# Episode 44/500, Total Reward: -9717.164199829102
# Episode 45/500, Total Reward: -9738.440246582031
# Episode 46/500, Total Reward: -9658.8115234375
# Episode 47/500, Total Reward: -9850.899780273438
# Episode 48/500, Total Reward: -9761.159530639648
# Episode 49/500, Total Reward: -9686.973373413086
# Episode 50/500, Total Reward: -9663.75260925293
# Episode 51/500, Total Reward: -9737.518783569336
# Episode 52/500, Total Reward: -9845.317031860352
# Episode 53/500, Total Reward: -9858.637817382812
# Episode 54/500, Total Reward: -9786.050643920898
# Episode 55/500, Total Reward: -9625.365798950195
# Episode 56/500, Total Reward: -9893.00080871582
# Episode 57/500, Total Reward: -9615.327514648438
# Episode 58/500, Total Reward: -9763.332626342773
# Episode 59/500, Total Reward: 4395.695068359375
# Episode 60/500, Total Reward: -351.94200134277344
# Episode 61/500, Total Reward: -9657.79946899414
# Episode 62/500, Total Reward: 2299.787612915039
# Episode 63/500, Total Reward: -9499.785903930664
# Episode 64/500, Total Reward: -9668.205505371094
# Episode 65/500, Total Reward: -9755.828353881836
# Episode 66/500, Total Reward: -9985.631271362305
# Episode 67/500, Total Reward: -9748.175765991211
# Episode 68/500, Total Reward: -9596.820129394531
# Episode 69/500, Total Reward: -9756.831451416016
# Episode 70/500, Total Reward: -9713.769958496094
# Episode 71/500, Total Reward: -9822.403457641602
# Episode 72/500, Total Reward: -9986.106994628906
# Episode 73/500, Total Reward: -9998.213027954102
# Episode 74/500, Total Reward: 5101.605941772461
# Episode 75/500, Total Reward: -9791.651306152344
# Episode 76/500, Total Reward: -9813.604629516602
# Episode 77/500, Total Reward: -9604.203674316406
# Episode 78/500, Total Reward: 2488.7874298095703
# Episode 79/500, Total Reward: -9866.188781738281
# Episode 80/500, Total Reward: -9670.834350585938
# Episode 81/500, Total Reward: -9829.634231567383
# Episode 82/500, Total Reward: -9843.764053344727
# Episode 83/500, Total Reward: -9897.707168579102
# Episode 84/500, Total Reward: -9779.360061645508
# Episode 85/500, Total Reward: -9799.238418579102
# Episode 86/500, Total Reward: -9729.752624511719
# Episode 87/500, Total Reward: -9962.992950439453
# Episode 88/500, Total Reward: 16104.991683959961
# Episode 89/500, Total Reward: -9744.470397949219
# Episode 90/500, Total Reward: -9853.324325561523
# Episode 91/500, Total Reward: -9766.650421142578
# Episode 92/500, Total Reward: -9774.349502563477
# Episode 93/500, Total Reward: -9717.116516113281
# Episode 94/500, Total Reward: -720.1254577636719
# Episode 95/500, Total Reward: -9804.514450073242
# Episode 96/500, Total Reward: -9577.118606567383
# Episode 97/500, Total Reward: 442.6257781982422
# Episode 98/500, Total Reward: -9828.350173950195
# Episode 99/500, Total Reward: -9630.813705444336
# Episode 100/500, Total Reward: -895.4246826171875
# Episode 101/500, Total Reward: 5028.268936157227
# Episode 102/500, Total Reward: -9599.737243652344
# Episode 103/500, Total Reward: -9756.45556640625
# Episode 104/500, Total Reward: -9604.67709350586
# Episode 105/500, Total Reward: -9693.201110839844
# Episode 106/500, Total Reward: -9750.540893554688
# Episode 107/500, Total Reward: -9630.518005371094
# Episode 108/500, Total Reward: 1769.732162475586
# Episode 109/500, Total Reward: -9738.809265136719
# Episode 110/500, Total Reward: -9760.373596191406
# Episode 111/500, Total Reward: 2330.8917083740234
# Episode 112/500, Total Reward: -9709.783462524414
# Episode 113/500, Total Reward: 3347.108169555664
# Episode 114/500, Total Reward: -9897.767303466797
# Episode 115/500, Total Reward: 8317.870010375977
# Episode 116/500, Total Reward: 6239.165252685547
# Episode 117/500, Total Reward: 10599.000839233398
# Episode 118/500, Total Reward: 2572.055435180664
# Episode 119/500, Total Reward: -9750.58757019043
# Episode 120/500, Total Reward: 10383.077041625977
# Episode 121/500, Total Reward: -9834.864776611328
# Episode 122/500, Total Reward: -9758.341751098633
# Episode 123/500, Total Reward: -9659.680465698242
# Episode 124/500, Total Reward: -9666.389907836914
# Episode 125/500, Total Reward: -9911.901992797852
# Episode 126/500, Total Reward: -718.7256774902344
# Episode 127/500, Total Reward: -9865.34780883789
# Episode 128/500, Total Reward: 18391.015502929688
# Episode 129/500, Total Reward: 7332.132797241211
# Episode 130/500, Total Reward: 7855.983917236328
# Episode 131/500, Total Reward: -9762.711502075195
# Episode 132/500, Total Reward: -9846.975463867188
# Episode 133/500, Total Reward: -9594.00617980957
# Episode 134/500, Total Reward: -9798.032257080078
# Episode 135/500, Total Reward: -9978.85661315918
# Episode 136/500, Total Reward: -9909.336669921875
# Episode 137/500, Total Reward: 4371.429870605469
# Episode 138/500, Total Reward: 1454.2673645019531
# Episode 139/500, Total Reward: -9773.48127746582
# Episode 140/500, Total Reward: -9646.416778564453
# Episode 141/500, Total Reward: 4264.086654663086
# Episode 142/500, Total Reward: -9751.706771850586
# Episode 143/500, Total Reward: -9978.604782104492
# Episode 144/500, Total Reward: -9760.246154785156
# Episode 145/500, Total Reward: -9711.090835571289
# Episode 146/500, Total Reward: -9868.732299804688
# Episode 147/500, Total Reward: -439.3812713623047
# Episode 148/500, Total Reward: -9695.028900146484
# Episode 149/500, Total Reward: -9985.950775146484
# Episode 150/500, Total Reward: -9790.430725097656
# Episode 151/500, Total Reward: -9764.073989868164
# Episode 152/500, Total Reward: -9595.913986206055
# Episode 153/500, Total Reward: -9782.046081542969
# Episode 154/500, Total Reward: -9841.966201782227
# Episode 155/500, Total Reward: -9989.977630615234
# Episode 156/500, Total Reward: -9758.287521362305
# Episode 157/500, Total Reward: -9810.999938964844
# Episode 158/500, Total Reward: -9795.2001953125
# Episode 159/500, Total Reward: -9660.792114257812
# Episode 160/500, Total Reward: -9654.174819946289
# Episode 161/500, Total Reward: -9626.62973022461
# Episode 162/500, Total Reward: -9651.46614074707
# Episode 163/500, Total Reward: -9748.05647277832
# Episode 164/500, Total Reward: 880.8752899169922
# Episode 165/500, Total Reward: -9640.318115234375
# Episode 166/500, Total Reward: -9765.558013916016
# Episode 167/500, Total Reward: 3243.4973907470703
# Episode 168/500, Total Reward: -9627.524520874023
# Episode 169/500, Total Reward: -9704.450637817383
# Episode 170/500, Total Reward: -9755.163955688477
# Episode 171/500, Total Reward: -9786.96711730957
# Episode 172/500, Total Reward: 4479.9002685546875
# Episode 173/500, Total Reward: -9856.757308959961
# Episode 174/500, Total Reward: -9742.963882446289
# Episode 175/500, Total Reward: -9783.242782592773
# Episode 176/500, Total Reward: -9828.750793457031
# Episode 177/500, Total Reward: 458.0825500488281
# Episode 178/500, Total Reward: -777.8746032714844
# Episode 179/500, Total Reward: -9607.218338012695
# Episode 180/500, Total Reward: -9712.585815429688
# Episode 181/500, Total Reward: -9760.273849487305
# Episode 182/500, Total Reward: -915.8422088623047
# Episode 183/500, Total Reward: -9755.103149414062
# Episode 184/500, Total Reward: -9722.622543334961
# Episode 185/500, Total Reward: -9757.370071411133
# Episode 186/500, Total Reward: -9952.554794311523
# Episode 187/500, Total Reward: -9982.586715698242
# Episode 188/500, Total Reward: -9753.486755371094
# Episode 189/500, Total Reward: -2518.3734588623047
# Episode 190/500, Total Reward: -9701.632873535156
# Episode 191/500, Total Reward: -9620.627716064453
# Episode 192/500, Total Reward: -9778.253311157227
# Episode 193/500, Total Reward: -9682.748016357422
# Episode 194/500, Total Reward: -9729.678100585938
# Episode 195/500, Total Reward: -9977.71517944336
# Episode 196/500, Total Reward: -9941.885040283203
# Episode 197/500, Total Reward: -1679.5934753417969
# Episode 198/500, Total Reward: -9925.056869506836
# Episode 199/500, Total Reward: -9998.272964477539
# Episode 200/500, Total Reward: -9616.445678710938
# Episode 201/500, Total Reward: -9717.729614257812
# Episode 202/500, Total Reward: -9792.387680053711
# Episode 203/500, Total Reward: -9870.165100097656
# Episode 204/500, Total Reward: -9952.72053527832
# Episode 205/500, Total Reward: 2626.4705810546875
# Episode 206/500, Total Reward: -9830.55940246582
# Episode 207/500, Total Reward: -9759.215301513672
# Episode 208/500, Total Reward: -9735.08757019043
# Episode 209/500, Total Reward: 3892.929885864258
# Episode 210/500, Total Reward: -9977.826477050781
# Episode 211/500, Total Reward: -9756.524047851562
# Episode 212/500, Total Reward: 3417.4193115234375
# Episode 213/500, Total Reward: 5462.178298950195
# Episode 214/500, Total Reward: -9715.300994873047
# Episode 215/500, Total Reward: -9807.114395141602
# Episode 216/500, Total Reward: -9628.858932495117
# Episode 217/500, Total Reward: 2222.3750610351562
# Episode 218/500, Total Reward: -9803.334106445312
# Episode 219/500, Total Reward: -479.9874572753906
# Episode 220/500, Total Reward: 146.97381591796875
# Episode 221/500, Total Reward: -9835.56982421875
# Episode 222/500, Total Reward: 3694.3682556152344
# Episode 223/500, Total Reward: 6202.071960449219
# Episode 224/500, Total Reward: -9725.752334594727
# Episode 225/500, Total Reward: 2045.6045684814453
# Episode 226/500, Total Reward: 5549.716018676758
# Episode 227/500, Total Reward: 641.4850158691406
# Episode 228/500, Total Reward: -9841.617477416992
# Episode 229/500, Total Reward: 6509.603988647461
# Episode 230/500, Total Reward: 1266.9602508544922
# Episode 231/500, Total Reward: -9809.585479736328
# Episode 232/500, Total Reward: -9986.299774169922
# Episode 233/500, Total Reward: -9720.371841430664
# Episode 234/500, Total Reward: 4406.732421875
# Episode 235/500, Total Reward: 4854.535247802734
# Episode 236/500, Total Reward: 837.8382415771484
# Episode 237/500, Total Reward: -9624.49006652832
# Episode 238/500, Total Reward: -9857.310165405273
# Episode 239/500, Total Reward: 6226.844757080078
# Episode 240/500, Total Reward: -9708.65478515625
# Episode 241/500, Total Reward: 369.7494354248047
# Episode 242/500, Total Reward: -9994.602249145508
# Episode 243/500, Total Reward: -9733.38996887207
# Episode 244/500, Total Reward: -554.7490692138672
# Episode 245/500, Total Reward: -9809.46566772461
# Episode 246/500, Total Reward: -9802.26742553711
# Episode 247/500, Total Reward: -9949.531875610352
# Episode 248/500, Total Reward: 9130.369140625
# Episode 249/500, Total Reward: -9977.254928588867
# Episode 250/500, Total Reward: -9983.686706542969
# Episode 251/500, Total Reward: -9632.505264282227
# Episode 252/500, Total Reward: -9799.813064575195
# Episode 253/500, Total Reward: -9779.108459472656
# Episode 254/500, Total Reward: 7458.465393066406
# Episode 255/500, Total Reward: -9586.615249633789
# Episode 256/500, Total Reward: -9521.063247680664
# Episode 257/500, Total Reward: 566.9832000732422
# Episode 258/500, Total Reward: -9981.22477722168
# Episode 259/500, Total Reward: -9779.381896972656
# Episode 260/500, Total Reward: -2625.645751953125
# Episode 261/500, Total Reward: -9616.623016357422
# Episode 262/500, Total Reward: -9924.087219238281
# Episode 263/500, Total Reward: -9750.725189208984
# Episode 264/500, Total Reward: 8481.109588623047
# Episode 265/500, Total Reward: -389.4208984375
# Episode 266/500, Total Reward: -9621.806533813477
# Episode 267/500, Total Reward: -9817.253051757812
# Episode 268/500, Total Reward: -9696.39714050293
# Episode 269/500, Total Reward: -9785.59976196289
# Episode 270/500, Total Reward: -9600.467514038086
# Episode 271/500, Total Reward: -9864.976852416992
# Episode 272/500, Total Reward: -9687.632431030273
# Episode 273/500, Total Reward: -9987.740631103516
# Episode 274/500, Total Reward: -9796.766845703125
# Episode 275/500, Total Reward: -9680.788116455078
# Episode 276/500, Total Reward: -9675.15739440918
# Episode 277/500, Total Reward: 5318.459625244141
# Episode 278/500, Total Reward: -9763.195556640625
# Episode 279/500, Total Reward: -9712.171875
# Episode 280/500, Total Reward: -9735.968032836914
# Episode 281/500, Total Reward: -9659.996322631836
# Episode 282/500, Total Reward: 7280.844345092773
# Episode 283/500, Total Reward: -9849.130905151367
# Episode 284/500, Total Reward: -9809.208587646484
# Episode 285/500, Total Reward: -9599.506439208984
# Episode 286/500, Total Reward: -9754.574676513672
# Episode 287/500, Total Reward: -9982.493560791016
# Episode 288/500, Total Reward: -9701.093826293945
# Episode 289/500, Total Reward: 3968.9403381347656
# Episode 290/500, Total Reward: 11695.128189086914
# Episode 291/500, Total Reward: -9722.463088989258
# Episode 292/500, Total Reward: 14034.794204711914
# Episode 293/500, Total Reward: -9683.485778808594
# Episode 294/500, Total Reward: -9752.055374145508
# Episode 295/500, Total Reward: -9671.054763793945
# Episode 296/500, Total Reward: -9654.601684570312
# Episode 297/500, Total Reward: 6033.505264282227
# Episode 298/500, Total Reward: 5138.948486328125
# Episode 299/500, Total Reward: 14952.263961791992
# Episode 300/500, Total Reward: -9813.267532348633
# Episode 301/500, Total Reward: -9604.578643798828
# Episode 302/500, Total Reward: 18105.07733154297
# Episode 303/500, Total Reward: -9604.561172485352
# Episode 304/500, Total Reward: -9635.20751953125
# Episode 305/500, Total Reward: 4392.383071899414
# Episode 306/500, Total Reward: 10512.671463012695
# Episode 307/500, Total Reward: -405.43284606933594
# Episode 308/500, Total Reward: -9807.92251586914
# Episode 309/500, Total Reward: 8071.027481079102
# Episode 310/500, Total Reward: -9741.087783813477
# Episode 311/500, Total Reward: -9759.93930053711
# Episode 312/500, Total Reward: -9994.926513671875
# Episode 313/500, Total Reward: -9936.131790161133
# Episode 314/500, Total Reward: 3256.471435546875
# Episode 315/500, Total Reward: 5974.969512939453
# Episode 316/500, Total Reward: 4843.956832885742
# Episode 317/500, Total Reward: -9828.268478393555
# Episode 318/500, Total Reward: 5148.041854858398
# Episode 319/500, Total Reward: -9821.819213867188
# Episode 320/500, Total Reward: -9945.939865112305
# Episode 321/500, Total Reward: 6351.194091796875
# Episode 322/500, Total Reward: -9793.048141479492
# Episode 323/500, Total Reward: -9995.628479003906
# Episode 324/500, Total Reward: -9990.27993774414
# Episode 325/500, Total Reward: -9658.839645385742
# Episode 326/500, Total Reward: 6251.423202514648
# Episode 327/500, Total Reward: -9593.365295410156
# Episode 328/500, Total Reward: -9891.66030883789
# Episode 329/500, Total Reward: -9831.93994140625
# Episode 330/500, Total Reward: 12085.92691040039
# Episode 331/500, Total Reward: 11508.874374389648
# Episode 332/500, Total Reward: 6207.373199462891
# Episode 333/500, Total Reward: 4649.807815551758
# Episode 334/500, Total Reward: 11911.755126953125
# Episode 335/500, Total Reward: -9765.91732788086
# Episode 336/500, Total Reward: -9656.091125488281
# Episode 337/500, Total Reward: 5989.792098999023
# Episode 338/500, Total Reward: 3368.4339447021484
# Episode 339/500, Total Reward: -9801.44906616211
# Episode 340/500, Total Reward: -9979.213897705078
# Episode 341/500, Total Reward: -9819.479721069336
# Episode 342/500, Total Reward: 8459.440216064453
# Episode 343/500, Total Reward: -9658.156234741211
# Episode 344/500, Total Reward: -9730.715072631836
# Episode 345/500, Total Reward: -9771.222885131836
# Episode 346/500, Total Reward: -9780.295318603516
# Episode 347/500, Total Reward: -9721.132705688477
# Episode 348/500, Total Reward: -9683.139846801758
# Episode 349/500, Total Reward: -9771.76382446289
# Episode 350/500, Total Reward: -9694.771896362305
# Episode 351/500, Total Reward: 9437.489822387695
# Episode 352/500, Total Reward: 8858.3720703125
# Episode 353/500, Total Reward: -9851.685638427734
# Episode 354/500, Total Reward: -9637.329055786133
# Episode 355/500, Total Reward: -9579.65852355957
# Episode 356/500, Total Reward: 10066.34457397461
# Episode 357/500, Total Reward: -9767.482971191406
# Episode 358/500, Total Reward: -9775.620574951172
# Episode 359/500, Total Reward: 15380.347885131836
# Episode 360/500, Total Reward: 344.5950469970703
# Episode 361/500, Total Reward: 8152.86946105957
# Episode 362/500, Total Reward: -9673.067459106445
# Episode 363/500, Total Reward: 11414.091110229492
# Episode 364/500, Total Reward: -9728.683242797852
# Episode 365/500, Total Reward: 5753.530563354492
# Episode 366/500, Total Reward: -9913.275619506836
# Episode 367/500, Total Reward: -9753.476547241211
# Episode 368/500, Total Reward: -9707.819061279297
# Episode 369/500, Total Reward: -9623.924514770508
# Episode 370/500, Total Reward: -9769.118698120117
# Episode 371/500, Total Reward: 8006.579544067383
# Episode 372/500, Total Reward: 6560.325668334961
# Episode 373/500, Total Reward: 3158.718017578125
# Episode 374/500, Total Reward: -9778.847122192383
# Episode 375/500, Total Reward: 5461.993515014648
# Episode 376/500, Total Reward: -9965.354721069336
# Episode 377/500, Total Reward: 5771.617034912109
# Episode 378/500, Total Reward: -9779.173797607422
# Episode 379/500, Total Reward: 2337.973419189453
# Episode 380/500, Total Reward: -9963.331985473633
# Episode 381/500, Total Reward: -9694.727233886719
# Episode 382/500, Total Reward: -9861.54037475586
# Episode 383/500, Total Reward: -9541.776336669922
# Episode 384/500, Total Reward: -9674.800338745117
# Episode 385/500, Total Reward: -9730.631149291992
# Episode 386/500, Total Reward: -9656.487167358398
# Episode 387/500, Total Reward: -9787.36572265625
# Episode 388/500, Total Reward: 5412.938064575195
# Episode 389/500, Total Reward: 1975.8026123046875
# Episode 390/500, Total Reward: -9803.601913452148
# Episode 391/500, Total Reward: 244.75341796875
# Episode 392/500, Total Reward: -9701.234924316406
# Episode 393/500, Total Reward: -9969.429336547852
# Episode 394/500, Total Reward: -9975.44563293457
# Episode 395/500, Total Reward: -9676.117202758789
# Episode 396/500, Total Reward: 3482.3311157226562
# Episode 397/500, Total Reward: -9623.145050048828
# Episode 398/500, Total Reward: -9602.270629882812
# Episode 399/500, Total Reward: -9865.581069946289
# Episode 400/500, Total Reward: -9674.914306640625
# Episode 401/500, Total Reward: 427.0479736328125
# Episode 402/500, Total Reward: -9781.314971923828
# Episode 403/500, Total Reward: -9744.079528808594
# Episode 404/500, Total Reward: 276.70985412597656
# Episode 405/500, Total Reward: 9222.956268310547
# Episode 406/500, Total Reward: -9721.650848388672
# Episode 407/500, Total Reward: 2788.6944122314453
# Episode 408/500, Total Reward: -9991.707702636719
# Episode 409/500, Total Reward: -9619.255096435547
# Episode 410/500, Total Reward: 1531.4946746826172
# Episode 411/500, Total Reward: -9971.047164916992
# Episode 412/500, Total Reward: -9854.208572387695
# Episode 413/500, Total Reward: 2394.9769439697266
# Episode 414/500, Total Reward: 10604.839172363281
# Episode 415/500, Total Reward: -9969.175765991211
# Episode 416/500, Total Reward: -9785.581481933594
# Episode 417/500, Total Reward: 3717.6239471435547
# Episode 418/500, Total Reward: -9846.078262329102
# Episode 419/500, Total Reward: -9929.8623046875
# Episode 420/500, Total Reward: -9976.756729125977
# Episode 421/500, Total Reward: 459.34983825683594
# Episode 422/500, Total Reward: 1914.4214782714844
# Episode 423/500, Total Reward: -9859.328643798828
# Episode 424/500, Total Reward: -9994.298797607422
# Episode 425/500, Total Reward: -9591.75357055664
# Episode 426/500, Total Reward: -9791.079391479492
# Episode 427/500, Total Reward: -9842.898330688477
# Episode 428/500, Total Reward: 596.1609802246094
# Episode 429/500, Total Reward: -9612.239959716797
# Episode 430/500, Total Reward: 1946.2963409423828
# Episode 431/500, Total Reward: -226.07211303710938
# Episode 432/500, Total Reward: -9960.260070800781
# Episode 433/500, Total Reward: -9700.091094970703
# Episode 434/500, Total Reward: -9930.366516113281
# Episode 435/500, Total Reward: -9790.401428222656
# Episode 436/500, Total Reward: -9901.668991088867
# Episode 437/500, Total Reward: -831.969970703125
# Episode 438/500, Total Reward: -9647.819702148438
# Episode 439/500, Total Reward: -9635.88003540039
# Episode 440/500, Total Reward: -9609.535522460938
# Episode 441/500, Total Reward: -9989.92904663086
# Episode 442/500, Total Reward: -9604.28547668457
# Episode 443/500, Total Reward: -9974.216766357422
# Episode 444/500, Total Reward: -9714.342163085938
# Episode 445/500, Total Reward: -9566.79345703125
# Episode 446/500, Total Reward: -9848.310958862305
# Episode 447/500, Total Reward: -1185.040023803711
# Episode 448/500, Total Reward: -9672.61572265625
# Episode 449/500, Total Reward: -9790.823852539062
# Episode 450/500, Total Reward: -9756.583801269531
# Episode 451/500, Total Reward: -9738.362014770508
# Episode 452/500, Total Reward: -650.7851867675781
# Episode 453/500, Total Reward: 1772.6963348388672
# Episode 454/500, Total Reward: -9614.69775390625
# Episode 455/500, Total Reward: -9859.894622802734
# Episode 456/500, Total Reward: -9826.249938964844
# Episode 457/500, Total Reward: -9897.79475402832
# Episode 458/500, Total Reward: -9540.046966552734
# Episode 459/500, Total Reward: -9783.347869873047
# Episode 460/500, Total Reward: -9914.260864257812
# Episode 461/500, Total Reward: -9697.632095336914
# Episode 462/500, Total Reward: 8976.21614074707
# Episode 463/500, Total Reward: -9960.249755859375
# Episode 464/500, Total Reward: -9998.262588500977
# Episode 465/500, Total Reward: -9949.529113769531
# Episode 466/500, Total Reward: -9580.014556884766
# Episode 467/500, Total Reward: -9960.72543334961
# Episode 468/500, Total Reward: -9979.240463256836
# Episode 469/500, Total Reward: -9650.568862915039
# Episode 470/500, Total Reward: -9761.622375488281
# Episode 471/500, Total Reward: 8081.660980224609
# Episode 472/500, Total Reward: -9738.676513671875
# Episode 473/500, Total Reward: 8675.597106933594
# Episode 474/500, Total Reward: 1860.3577117919922
# Episode 475/500, Total Reward: -9981.763427734375
# Episode 476/500, Total Reward: -9975.257400512695
# Episode 477/500, Total Reward: -9964.58706665039
# Episode 478/500, Total Reward: -9997.493637084961
# Episode 479/500, Total Reward: -1220.4599914550781
# Episode 480/500, Total Reward: 5395.027740478516
# Episode 481/500, Total Reward: -671.6503295898438
# Episode 482/500, Total Reward: -9741.498794555664
# Episode 483/500, Total Reward: -9706.632843017578
# Episode 484/500, Total Reward: 551.1148223876953
# Episode 485/500, Total Reward: 7433.21745300293
# Episode 486/500, Total Reward: -9949.551208496094
# Episode 487/500, Total Reward: 6728.4893798828125
# Episode 488/500, Total Reward: -9997.576431274414
# Episode 489/500, Total Reward: 1353.0345764160156
# Episode 490/500, Total Reward: -9771.46353149414
# Episode 491/500, Total Reward: -9652.549911499023
# Episode 492/500, Total Reward: 2511.439468383789
# Episode 493/500, Total Reward: -9898.665542602539
# Episode 494/500, Total Reward: 984.7811889648438
# Episode 495/500, Total Reward: -9743.614517211914
# Episode 496/500, Total Reward: -9553.88623046875
# Episode 497/500, Total Reward: -9935.756469726562
# Episode 498/500, Total Reward: -9978.469635009766
# Episode 499/500, Total Reward: 3482.6617431640625
# Episode 500/500, Total Reward: -9832.822250366211
# Training Complete!

# %% [markdown]
# ## 🔬 Inferencing the AI Agent:
#
# Testing the agent on new market data by allowing it to make decisions without random exploration:

# %%
# Creating a fresh environment instance for testing:
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

# Simulating a trading session using the trained AI Agent:
while not done:
    # Always choose the best action (exploitation):
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance After Testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\3618060542.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# C:\Users\sandh\AppData\Local\Temp\ipykernel_2672\716196290.py:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Final Balance After Testing: $32908.82
# Total Profit: $22908.82

# %% [markdown]
# ## 📊 Results:
#
# The agent started with: **$10,000**
#
# And ended with: **$32,908.82**
#
# Profit = $22908.82, meaning the agent made a **great positive return**
